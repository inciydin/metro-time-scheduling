# %%
import pandas as pd

data = pd.read_csv('hourly_transportation_202401.csv')

# %%
pd.set_option('display.max_rows', 100)
pd.options.display.max_rows
# Out:
# 100

# %%
data.head(100)
# Out:
#    transition_date  transition_hour  transport_type_id road_type  \
# 0       2024-01-01                0                  1    OTOYOL
# 1       2024-01-01                0                  1    OTOYOL
# 2       2024-01-01                0                  1    OTOYOL
# 3       2024-01-01                0                  1    OTOYOL
# 4       2024-01-01                0                  1    OTOYOL
# 5       2024-01-01                0                  1    OTOYOL
# 6       2024-01-01                0                  1    OTOYOL
# 7       2024-01-01                0                  1    OTOYOL
# 8       2024-01-01                0                  3     DENİZ
# 9       2024-01-01                0                  1    OTOYOL
# 10      2024-01-01                0                  1    OTOYOL
# 11      2024-01-01                0                  1    OTOYOL
# 12      2024-01-01                0                  1    OTOYOL
# 13      2024-01-01                0                  1    OTOYOL
# 14      2024-01-01                0                  2     RAYLI
# 15      2024-01-01                0                  1    OTOYOL
# 16      2024-01-01                0                  2     RAYLI
# 17      2024-01-01                0                  1    OTOYOL
# 18      2024-01-01                0                  1    OTOYOL
# 19      2024-01-01                0                  1    OTOYOL
# 20      2024-01-01                0                  3     DENİZ
# 21      2024-01-01                0                  3     DENİZ
# 22      2024-01-01                0                  1    OTOYOL
# 23      2024-01-01                0                  1    OTOYOL
# 24      2024-01-01                0                  1    OTOYOL
# 25      2024-01-01                0                  1    OTOYOL
# 26      2024-01-01                0                  1    OTOYOL
# 27      2024-01-01                0                  1    OTOYOL
# 28      2024-01-01                0                  1    OTOYOL
# 29      2024-01-01                0                  1    OTOYOL
# 30      2024-01-01                0                  1    OTOYOL
# 31      2024-01-01                0                  1    OTOYOL
# 32      2024-01-01                0                  1    OTOYOL
# 33      2024-01-01                0                  1    OTOYOL
# 34      2024-01-01                0                  1    OTOYOL
# 35      2024-01-01                0                  1    OTOYOL
# 36      2024-01-01                0                  1    OTOYOL
# 37      2024-01-01                0                  1    OTOYOL
# 38      2024-01-01                0                  3     DENİZ
# 39      2024-01-01                0                  1    OTOYOL
# 40      2024-01-01                0                  1    OTOYOL
# 41      2024-01-01                0                  2     RAYLI
# 42      2024-01-01                0                  2     RAYLI
# 43      2024-01-01                0                  1    OTOYOL
# 44      2024-01-01                0                  1    OTOYOL
# 45      2024-01-01                0                  2     RAYLI
# 46      2024-01-01                0                  2     RAYLI
# 47      2024-01-01                0                  2     RAYLI
# 48      2024-01-01                0                  1    OTOYOL
# 49      2024-01-01                0                  3     DENİZ
# 50      2024-01-01                0                  1    OTOYOL
# 51      2024-01-01                0                  1    OTOYOL
# 52      2024-01-01                0                  2     RAYLI
# 53      2024-01-01                0                  1    OTOYOL
# 54      2024-01-01                0                  3     DENİZ
# 55      2024-01-01                0                  1    OTOYOL
# 56      2024-01-01                0                  1    OTOYOL
# 57      2024-01-01                0                  1    OTOYOL
# 58      2024-01-01                0                  1    OTOYOL
# 59      2024-01-01                0                  1    OTOYOL
# 60      2024-01-01                0                  2     RAYLI
# 61      2024-01-01                0                  1    OTOYOL
# 62      2024-01-01                0                  1    OTOYOL
# 25                                 KADIKOY-YENIDOGAN        Normal
# 26                                 KADIKOY-YENIDOGAN        Normal
# 27                                   CEBECI - TAKSIM        Normal
# 28                                 KADIKOY-ESENEVLER        Normal
# 29                                 SARIYER - KABATAS        Normal
# 30                            ISTINYE DEREICI-TAKSIM        Normal
# 31                                    KADIKOY-PENDIK        Normal
# 32                   ADEM YAVUZ MAH-ZIVERBEY-KADIKOY        Normal
# 33                                   KADIKOY-USKUDAR        Normal
# 34                             TARABYAUSTU - KABATAS        Normal
# 35                                  KADIKOY-BOSTANCI        Normal
# 36                         YENIDOGAN-TOPKAPI KALEICI        Normal
# 37                                 KADIKOY-ESENSEHIR        Normal
# 38                                  BESIKTAS-USKUDAR        Normal
# 39                 HACI OSMAN METRO -  RUMELI FENERI        Normal
# 40            ISTINYE DEREICI - FERAHEVLER - KABATAS        Normal
# 41                                 LEVENT-HISAR USTU       Aktarma
# 42                                  KABATAS-BAGCILAR        Normal
# 43                                 KADIKOY-YENIDOGAN        Normal
# 44                          RUMELI HISARUSTU - SISLI        Normal
# 45                             YENIKAPI - HAVALIMANI       Aktarma
# 46                             YENIKAPI - HAVALIMANI        Normal
# 47                 GAYRETTEPE-ISTANBUL YENI HAVALIMA        Normal
# 48                                   SILIVRI-AVCILAR        Normal
# 49                                  BESIKTAS-USKUDAR        Normal
# 50  KADIKOY-FINDIKLI MAHALLESI-YEDITEPE UNIVERSITESI        Normal
# 51                  KADIKOY-RASATHANE-ANADOLU HISARI        Normal
# 52                             YENIKAPI - HAVALIMANI        Normal
# 53                               USKUDAR-ALTBOSTANCI        Normal
# 54                                 KARAKOY-Y.KADIKOY        Normal
# 55                   GUVERCINTEPE-OLIMPIYATKOY METRO       Aktarma
# 56                       SULTANBEYLI(GOLET)- KADIKOY        Normal
# 57                  MIMARSINAN – I.U.AVCILAR KAMPUSU       Aktarma
# 58              SARIYER-HACIOSMAN-MECIDIYEKOY-TAKSIM        Normal
# 59                      SAHINTEPE-OLIMPIYATKOY METRO       Aktarma
# 60                                    KADIKOY-KARTAL        Normal
# 61                                   KADIKOY-ALEMDAG        Normal
# 62                      YENIDOGAN/ATASEHIR - KADIKOY       Aktarma
# 63                   ZUBEYDE HANIM MAHALLESI-BEYAZIT        Normal
# 64                 BASAKSEHIR 4 -1. ETAPLAR - TAKSIM        Normal
# 65                                    KADIKOY - MODA        Normal
# 66                    FATIH SULTAN MEHMET - BESIKTAS        Normal
# 67                 SAHINTEPE - AVCILAR-CIHANGIR MAH.        Normal
# 68                   ADEM YAVUZ MAH-ZIVERBEY-KADIKOY        Normal
# 69                                 KADIKOY-YENIDOGAN       Aktarma
# 70                  CIHANGIR MAH. - AVCILAR - OTOGAR        Normal
# 71                  CIHANGIR MAH. - AVCILAR - OTOGAR        Normal
# 72                             EDIRNEKAPI - BESIKTAS        Normal
# 73                   YUNUS EMRE MAHALLESI-VEZNECILER        Normal
# 74                                  BESIKTAS-USKUDAR        Normal
# 75                                 KADIKOY-ESENSEHIR        Normal
# 76                        DERESEKI /BEYKOZ - KADIKOY        Normal
# 77                   YUNUS EMRE MAHALLESI-VEZNECILER        Normal
# 78                                  TOPKAPI-HABIBLER        Normal
# 79                                  TAKSIM - KABATAS        Normal
# 80                                 KARAKOY-Y.KADIKOY        Normal
# 81                                 KADIKOY-ESENSEHIR        Normal
# 82                       KAYABASI KIPTAS-MECIDIYEKOY       Aktarma
# 83                         SULTAN CIFTLIGI - EMINONU        Normal
# 84                                   ADALAR-BOSTANCI        Normal
# 85                                 LEVENT-HISAR USTU        Normal
# 86                 BASAKSEHIR 4 -1. ETAPLAR - TAKSIM       Aktarma
# 87                         ZINCIRLIKUYU-SOGUTLUCESME        Normal
# 88                                    KADIKOY-BEYKOZ        Normal
# 89                      KIRAZLI-BASAKSEHIR/METROKENT        Normal
# 90                           SULTANBEYLI-MECIDIYEKOY        Normal
# 91                               CEBECI-ZINCIRLIKUYU       Aktarma
# 92                 BASAKSEHIR 4 -1. ETAPLAR - TAKSIM        Normal
# 93                MECIDIYEKOY - BASAKSEHIR METROKENT        Normal
# 94                           KARTAL-VEYSELKARANI MAH        Normal
# 95                            BESIKTAS - MECIDIYEKOY        Normal
# 96                         HACI OSMAN METRO - KILYOS        Normal
# 97                                ZEYTINBURNU-TAKSIM        Normal
# 98                                BOSTANCI - DUDULLU        Normal
# 99                              SULTANBEYLI-UMRANIYE        Normal
#
#     number_of_passage  number_of_passenger
# 0                  16                   13
# 1                   1                    1
# 2                   1                    1
# 3                   1                    1
# 4                   1                    1
# 5                   1                    1
# 6                 106                  106
# 7                  58                   49
# 8                   1                    1
# 9                   6                    6
# 10                  1                    1
# 11                  1                    1
# 12                  1                    1
# 13                  2                    2
# 14                  1                    1
# 15                  2                    2
# 16                 30                   27
# 17                  4                    4
# 18                  1                    1
# 19                  4                    4
# 20                  9                    9
# 21                  4                    4
# 22                  1                    1
# 23                 17                   14
# 24                 31                   31
# 25                 31                   31
# 26                  1                    1
# 27                 18                   18
# 28                  5                    3
# 29                  3                    3
# 30                 45                   27
# 31                  1                    1
# 32                  6                    6
# 33                 70                   69
# 34                  1                    1
# 35                 10                    9
# 36                  1                    1
# 37                 35                   35
# 38                  3                    3
# 39                  2                    1
# 40                  4                    4
# 41                 44                   44
# 42                346                  345
# 43                  4                    4
# 44                  2                    2
# 45                  2                    2
# 46               1509                 1131
# 47                  8                    8
# 48                  9                    8
# 49                 12                   12
# 50                  8                    8
# 51                 25                   25
# 52                178                  178
# 53                  1                    1
# 54                  2                    2
# 55                  1                    1
# 56                 24                   21
# 57                  1                    1
# 58                  2                    2
# 59                  9                    9
# 60                236                  232
# 61                 15                   15
# 62                  1                    1
# 63                 27                   18
# 64                  1                    1
# 65                  1                    1
# 66                  6                    3
# 67                  8                    4
# 68                  6                    6
# 69                  3                    3
# 70                  1                    1
# 71                  1                    1
# 72                  7                    5
# 73                  5                    4
# 74                  4                    3
# 75                  4                    4
# 76                  8                    8
# 77                  1                    1
# 78                 11                   11
# 79                 43                   43
# 80                 56                   42
# 81                  7                    6
# 82                  2                    2
# 83                  1                    1
# 84                 35                   33
# 85                233                  233
# 86                  8                    8
# 87                  1                    1
# 88                 64                   64
# 89                  5                    4
# 90                  5                    5
# 91                  2                    2
# 92                  5                    5
# 93                  2                    2
# 94                  1                    1
# 95                  2                    2
# 96                  2                    1
# 97                 59                   48
# 98                 20                   20
# 99                  1                    1

# %%
filtered = data[(data['road_type'] == 'RAYLI') & (data['line'] == 'YENIKAPI - HACIOSMAN')]

# %%
filtered.head(20)
# Out:
#      transition_date  transition_hour  transport_type_id road_type  \
# 115       2024-01-01                0                  2     RAYLI
# 207       2024-01-01                0                  2     RAYLI
# 217       2024-01-01                0                  2     RAYLI
# 295       2024-01-01                0                  2     RAYLI
# 307       2024-01-01                0                  2     RAYLI
# 380       2024-01-01                0                  2     RAYLI
# 468       2024-01-01                0                  2     RAYLI
# 544       2024-01-01                0                  2     RAYLI
# 625       2024-01-01                0                  2     RAYLI
# 660       2024-01-01                0                  2     RAYLI
# 670       2024-01-01                0                  2     RAYLI
# 677       2024-01-01                0                  2     RAYLI
# 763       2024-01-01                0                  2     RAYLI
# 821       2024-01-01                0                  2     RAYLI
# 884       2024-01-01                0                  2     RAYLI
# 911       2024-01-01                0                  2     RAYLI
# 950       2024-01-01                0                  2     RAYLI
# 1084      2024-01-01                0                  2     RAYLI
# 1132      2024-01-01                0                  2     RAYLI
# 1178      2024-01-01                0                  2     RAYLI
#
#                       line transfer_type  number_of_passage  \
# 115   YENIKAPI - HACIOSMAN        Normal               2617
# 207   YENIKAPI - HACIOSMAN        Normal                  4
# 217   YENIKAPI - HACIOSMAN        Normal                 27
# 295   YENIKAPI - HACIOSMAN       Aktarma                156
# 307   YENIKAPI - HACIOSMAN        Normal                198
# 380   YENIKAPI - HACIOSMAN       Aktarma                  2
# 468   YENIKAPI - HACIOSMAN        Normal                 46
# 544   YENIKAPI - HACIOSMAN       Aktarma                275
# 625   YENIKAPI - HACIOSMAN       Aktarma                  2
# 660   YENIKAPI - HACIOSMAN        Normal                 69
# 670   YENIKAPI - HACIOSMAN       Aktarma                865
# 677   YENIKAPI - HACIOSMAN        Normal                609
# 763   YENIKAPI - HACIOSMAN        Normal                372
# 821   YENIKAPI - HACIOSMAN        Normal                  8
# 884   YENIKAPI - HACIOSMAN       Aktarma                  9
# 911   YENIKAPI - HACIOSMAN        Normal               5978
# 950   YENIKAPI - HACIOSMAN        Normal                 14
# 1084  YENIKAPI - HACIOSMAN       Aktarma                 31
# 1132  YENIKAPI - HACIOSMAN        Normal                 58
# 1178  YENIKAPI - HACIOSMAN        Normal                886
#
#       number_of_passenger
# 115                  2581
# 207                     4
# 217                    22
# 295                   155
# 307                   196
# 380                     2
# 468                    35
# 544                   273
# 625                     2
# 660                    69
# 670                   857
# 677                   609
# 763                   364
# 821                     6
# 884                     9
# 911                  4084
# 950                    14
# 1084                   31
# 1132                   50
# 1178                  736

# %%
total_counts = {}

# %%
for row in filtered.itertuples():
    date = row.transition_date
    hour = str(row.transition_hour)
    if date not in total_counts:
        total_counts[date] = {}
    if hour not in total_counts[date]:
        total_counts[date][hour] = 0
    total_counts[date][hour] += 1

# %%
total_counts['2024-01-01']['5']
# Out:
# 18

# %%
def divide_items_into_groups(total_items):
    group_count = 3
    base_group_size = total_items // group_count
    remainder = total_items % group_count
    groups = [base_group_size] * group_count
    
    for i in range(remainder):
        groups[i] += 1
    
    return {'0': groups[0], '20': groups[1], '40': groups[2]}

# %%
group_counts = {}

# %%
for date, date_value in total_counts.items():
    group_counts[date] = {}
    for hour, count in date_value.items():
        group_counts[date][hour] = divide_items_into_groups(count)

# %%
sums = {}

for row in filtered.itertuples():
    date = row.transition_date
    hour = str(row.transition_hour)

    if date not in sums:
        sums[date] = {}
    if hour not in sums[date]:
        sums[date][hour] = {
            '0': {'count': 0, 'value': 0},
            '20': {'count': 0, 'value': 0},
            '40': {'count': 0, 'value': 0},
        }
    
    i = None

    if sums[date][hour]['0']['count'] < group_counts[date][hour]['0']:
        i = '0'
    elif sums[date][hour]['20']['count'] < group_counts[date][hour]['20']:
        i = '20'
    elif sums[date][hour]['40']['count'] < group_counts[date][hour]['40']:
        i = '40'

    if i is not None:
        sums[date][hour][i]['count'] += 1
        sums[date][hour][i]['value'] += row.number_of_passage

# %%
from datetime import datetime

def get_day(date_str):
    date_obj = datetime.strptime(date_str, "%Y-%m-%d")
    day = date_obj.strftime("%A")
    if day in ['Saturday', 'Sunday']:
        return day.lower()
    return 'weekday'

# %%
import json
# json.dumps(sums)

# %%
sums_by_days = {
    'weekday': {},
    'saturday': {},
    'sunday': {},
}

for date, date_value in sums.items():
    day_of_week = get_day(date)
    
    for hour, hour_value in date_value.items():    
        if hour not in sums_by_days[day_of_week]:
            sums_by_days[day_of_week][hour] = {
                '0': {'value': 0, 'count': 0},
                '20': {'value': 0, 'count': 0},
                '40': {'value': 0, 'count': 0},
            }

        for i in ['0', '20', '40']:
            sums_by_days[day_of_week][hour][i]['value'] += hour_value[i]['value']
            sums_by_days[day_of_week][hour][i]['count'] += 1

# %%
import json

# print(json.dumps(sums_by_days, indent=4))

# %%
means_by_intervals = {
    'weekday': {},
    'saturday': {},
    'sunday': {},
} 

for day, day_value in sums_by_days.items():
    for hour, hour_value in day_value.items():
        if hour not in means_by_intervals[day]:
            means_by_intervals[day][hour] = {}
            
        for minute, minute_value in hour_value.items():
            means_by_intervals[day][hour][minute] = minute_value['value'] / minute_value['count']

# %%
means_df = pd.DataFrame(columns=[
    "weekday_0", "weekday_20", "weekday_40", 
    "saturday_0", "saturday_20", "saturday_40",  
    "sunday_0", "sunday_20", "sunday_40",
])

for day, day_value in means_by_intervals.items():
    for hour, hour_value in day_value.items():
        for minute, mean in hour_value.items():
            col_name = f'{day}_{minute}'
            if hour not in means_df.index:
                means_df.loc[hour] = pd.Series(dtype='float')
            means_df.at[hour, col_name] = mean

# %%
means_df
# Out:
#        weekday_0    weekday_20    weekday_40  saturday_0  saturday_20  \
# 0     281.782609    216.565217    407.130435      863.00      1411.25
# 1    1952.000000   5866.000000   3278.000000      706.00       318.00
# 2    6615.000000    871.000000    429.000000      407.50       223.50
# 3    4081.000000   1049.000000    521.000000      301.00        80.00
# 4    1529.000000   1129.000000     83.000000      143.00       174.75
# 18      25664       19236       15452        8077        11974        11279
# 19      10401       13130       13308       10348         7537         9007
# 20       7553        7250        5595        8081         1822         8716
# 21       6355        4347        4579        6530         3673         4799
# 22       5831        4933        5047        3452         5531         5513
# 23       2204        2648        3212        4486         1675         2843
#
#     sunday_0  sunday_20  sunday_40
# 6        515       1654       1348
# 7       2500       1623       1619
# 8       2138       3657       2131
# 9       2841       2902       2948
# 10      4734       2757       2108
# 11      3001       3585       4513
# 12      4463       4711       4339
# 13      7623       3767       6188
# 14      4812       7050       8048
# 15      7778       8050       6128
# 16      8644       8064       5216
# 17      8097       6303       9152
# 18      7214       6662       9554
# 19      6176       8019       4464
# 20      5518       2891       6405
# 21      7531       3493       3193
# 22      5380       3778       2693
# 23      1961       2584       1783

# %%
means_df_filtered.to_csv('mean.csv')

# %%
from math import ceil

def find_nearest(value, round_list):
    greater_values = [num for num in round_list if num > value]
    
    if greater_values:
        return min(greater_values, key=lambda x: abs(x - value))
    else:
        return min(round_list, key=lambda x: abs(x - value))

def calc_mins_between_vhcs(vehicle_capacity, time_interval, passenger_demand, possible_values=None):
    value = (time_interval * vehicle_capacity / passenger_demand)

    if possible_values:
        return value, find_nearest(value, possible_values)
    return value, ceil(value)

# %%
vehicle_capacity = 2600
time_interval = 20
possible_values = [4, 5, 6, 7, 8, 10, 12, 15]

exact_value, result = calc_mins_between_vhcs(vehicle_capacity, time_interval, 5000, possible_values=possible_values)

print(f"Exact Value    : {exact_value}")
print(f"Result         : {result}")
print(f"Possible Values: {', '.join(map(str, possible_values))}")
# Out:
# Exact Value    : 10.4
# Result         : 12
# Possible Values: 4, 5, 6, 7, 8, 10, 12, 15

# %%
apply_fn = lambda x: calc_mins_between_vhcs(vehicle_capacity, time_interval, x, possible_values=possible_values)[1]

calculated = means_df_filtered.apply(lambda x: x.map(apply_fn))

# %%
calculated
# Out:
#     weekday_0  weekday_20  weekday_40  saturday_0  saturday_20  saturday_40  \
# 6          15          15          15          15           15           15
# 7           5           8           7          15           15           15
# 8           4           4           5          15           10           10
# 9           5           7           5          12           12           10
# 10          6           8          10          12           10           15
# 11          7           8           8          15           10           10
# 12          8           8           6           8            7           15
# 13          6           7           7           6           10            5
# 14          7           5           7           7            6            5
# 15          6           5           5           6            6            6
# 16          4           4           5           5            5            8
# 17          5           4           4           6            8            4
# 18          4           4           4           7            5            5
# 19          5           4           4           6            7            6
# 20          7           8          10           7           15            6
# 21         10          12          12           8           15           12
# 22         10          12          12          15           10           10
# 23         15          15          15          12           15           15
#
#     sunday_0  sunday_20  sunday_40
# 6         15         15         15
# 7         15         15         15
# 8         15         15         15
# 9         15         15         15
# 10        12         15         15
# 11        15         15         12
# 12        12         12         12
# 13         7         15         10
# 14        12          8          7
# 15         7          7         10
# 16         7          7         10
# 17         7         10          6
# 18         8          8          6
# 19        10          7         12
# 20        10         15         10
# 21         7         15         15
# 22        10         15         15
# 23        15         15         15

# %%
calculated.to_csv('calculated.csv')

# %%
import seaborn
# %matplotlib inline

seaborn.heatmap(calculated, annot=True)
# Out:
# <Axes: >
